# %% [markdown]
# # 多元统计分析作业——爬取安居客房价
#
# > 所有数据均来源于安居客网站。
# > Copyright © 2007-2019 www.anjuke.com All Rights Reserved

# %%
# Requirements: requests, numpy, pandas, lxml, time, csv, sys
# 必要时可以设置time.sleep(2)消除屏蔽机制，不过安居客好像没有

url = 'https://www.anjuke.com/fangjia/'
HEADERS={
    'Cookie': '',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7,zh-TW;q=0.6',
}

# %% [markdown]
# # 爬取省的链接以及名称

# %%
import requests
from lxml import etree

response = requests.get(url,headers=HEADERS)
text = response.text
main_page = etree.HTML(text)
province_links = main_page.xpath('/html/body/div[2]/div[2]/div/span[2]/a/@href')
province = main_page.xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()')

# %%
print(province_links)
print(province)
# Out:
# ['http://www.anjuke.com/fangjia/yixianchengshi/', 'http://www.anjuke.com/fangjia/anhui/', 'http://www.anjuke.com/fangjia/fujian/', 'http://www.anjuke.com/fangjia/gansu/', 'http://www.anjuke.com/fangjia/guangdong/', 'http://www.anjuke.com/fangjia/guangxi/', 'http://www.anjuke.com/fangjia/guizhou/', 'http://www.anjuke.com/fangjia/hainan/', 'http://www.anjuke.com/fangjia/hebei/', 'http://www.anjuke.com/fangjia/heilongjiang/', 'http://www.anjuke.com/fangjia/henan/', 'http://www.anjuke.com/fangjia/hubei/', 'http://www.anjuke.com/fangjia/hunan/', 'http://www.anjuke.com/fangjia/jiangsu/', 'http://www.anjuke.com/fangjia/jiangxi/', 'http://www.anjuke.com/fangjia/jilin/', 'http://www.anjuke.com/fangjia/liaoning/', 'http://www.anjuke.com/fangjia/neimenggu/', 'http://www.anjuke.com/fangjia/ningxia/', 'http://www.anjuke.com/fangjia/qinghai/', 'http://www.anjuke.com/fangjia/shan3xi/', 'http://www.anjuke.com/fangjia/shandong/', 'http://www.anjuke.com/fangjia/shanxi/', 'http://www.anjuke.com/fangjia/sichuan/', 'http://www.anjuke.com/fangjia/xinjiang/', 'http://www.anjuke.com/fangjia/xizang/', 'http://www.anjuke.com/fangjia/yunnan/', 'http://www.anjuke.com/fangjia/zhejiang/']
# ['一线城市', '安徽', '福建', '甘肃', '广东', '广西', '贵州', '海南', '河北', '黑龙江', '河南', '湖北', '湖南', '江苏', '江西', '吉林', '辽宁', '内蒙古', '宁夏', '青海', '陕西', '山东', '山西', '四川', '新疆', '西藏', '云南', '浙江']

# %% [markdown]
# # 爬取市的链接和名称

# %%
# 收集城市
city_links_all = []
city_all = []
for province_url in province_links:
    province_response = requests.get(province_url,headers=HEADERS)
    city_links_all.append(etree.HTML(province_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/div/a/@href'))
    city_all.append(etree.HTML(province_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/div/a/text()'))

# %%
print(city_all) 
# 可以看到城市之中有重复的，所以需要进行清洗去除重复的城市;而且这里还存在空的情况，海南和吉林后面会进行处理
# Out:
# [['北京', '重庆', '上海', '天津'], ['安庆', '蚌埠', '亳州', '巢湖', '池州', '滁州', '阜阳', '合肥', '和县', '霍邱', '淮北', '淮南', '黄山', '霍邱', '六安', '马鞍山', '宿州', '桐城', '桐城', '铜陵', '芜湖', '宣城'], ['福州', '龙岩', '南平', '宁德', '莆田', '泉州', '三明', '武夷山', '厦门', '漳州'], ['白银', '定西', '定西', '甘南', '甘南', '嘉峪关', '金昌', '金昌', '酒泉', '嘉峪关', '兰州', '临夏', '陇南', '陇南', '临夏', '平凉', '平凉', '庆阳', '天水', '武威', '张掖', '张掖'], ['潮州', '东莞', '佛山', '广州', '河源', '惠州', '江门', '揭阳', '茂名', '梅州', '清远', '汕头', '汕尾', '韶关', '深圳', '顺德', '台山', '台山', '阳春', '阳春', '阳江', '云浮', '云浮', '湛江', '肇庆', '中山', '珠海'], ['百色', '北海', '崇左', '崇左', '防城港', '防城港', '贵港', '桂林', '河池', '河池', '贺州', '贺州', '来宾', '来宾', '柳州', '南宁', '钦州', '梧州', '玉林'], ['安顺', '毕节', '毕节', '贵阳', '六盘水', '黔东南', '黔东南', '黔南', '黔西南', '黔南', '黔西南', '铜仁', '铜仁', '遵义'], [], ['保定', '沧州', '承德', '定州', '定州', '馆陶', '邯郸', '衡水', '廊坊', '秦皇岛', '石家庄', '唐山', '邢台', '张北', '张家口', '赵县', '正定', '赵县'], ['大庆', '大兴安岭', '大兴安岭', '哈尔滨', '鹤岗', '黑河', '黑河', '佳木斯', '鸡西', '牡丹江', '齐齐哈尔', '七台河', '七台河', '双鸭山', '绥化', '双鸭山', '伊春', '伊春'], ['安阳', '长葛', '长葛', '鹤壁', '焦作', '济源', '开封', '漯河', '洛阳', '明港', '南阳', '平顶山', '濮阳', '三门峡', '商丘', '新乡', '信阳', '许昌', '鄢陵', '鄢陵', '禹州', '禹州', '郑州', '周口', '驻马店'], ['恩施', '鄂州', '黄冈', '黄石', '荆门', '荆州', '潜江', '潜江', '神农架', '十堰', '随州', '天门', '天门', '武汉', '襄阳', '咸宁', '仙桃', '孝感', '宜昌'], ['常德', '长沙', '郴州', '衡阳', '怀化', '娄底', '邵阳', '湘潭', '湘西', '湘西', '益阳', '永州', '岳阳', '张家界', '株洲'], ['常州', '大丰', '淮安', '昆山', '连云港', '南京', '南通', '沭阳', '宿迁', '苏州', '太仓', '泰州', '无锡', '徐州', '盐城', '扬州', '镇江'], ['抚州', '赣州', '吉安', '景德镇', '九江', '南昌', '萍乡', '上饶', '新余', '宜春', '鹰潭', '永新'], [], ['鞍山', '本溪', '朝阳', '朝阳', '大连', '丹东', '抚顺', '阜新', '葫芦岛', '锦州', '辽阳', '盘锦', '沈阳', '铁岭', '瓦房店', '瓦房店', '营口', '庄河', '庄河'], ['阿拉善盟', '包头', '巴彦淖尔市', '巴彦淖尔市', '赤峰', '鄂尔多斯', '海拉尔', '呼和浩特', '呼伦贝尔', '通辽', '乌海', '乌兰察布', '锡林郭勒盟', '兴安盟'], ['固原', '石嘴山', '中卫', '吴忠', '吴忠', '中卫', '银川'], ['果洛', '海北', '海东', '海东', '海南', '海西', '黄南', '海西', '西宁', '玉树'], ['安康', '宝鸡', '汉中', '商洛', '商洛', '铜川', '铜川', '渭南', '西安', '咸阳', '延安', '榆林'], ['滨州', '德州', '东营', '菏泽', '济南', '济宁', '垦利', '莱芜', '聊城', '临沂', '青岛', '日照', '泰安', '潍坊', '威海', '烟台', '枣庄', '章丘', '诸城', '淄博'], ['长治', '大同', '晋城', '晋中', '临汾', '临猗', '吕梁', '吕梁', '清徐', '清徐', '朔州', '太原', '忻州', '阳泉', '运城'], ['阿坝', '巴中', '成都', '达州', '德阳', '广元', '甘孜', '广安', '乐山', '凉山', '泸州', '眉山', '绵阳', '南充', '内江', '攀枝花', '遂宁', '雅安', '雅安', '宜宾', '自贡', '资阳'], ['阿克苏', '阿克苏', '阿拉尔', '巴音郭楞', '博尔塔拉', '博尔塔拉', '昌吉', '哈密', '和田', '和田', '喀什', '克拉玛依', '克孜勒苏', '克孜勒苏', '石河子', '吐鲁番', '吐鲁番', '图木舒克', '五家渠', '乌鲁木齐', '伊犁'], ['阿里', '昌都', '昌都', '拉萨', '林芝', '那曲', '那曲', '日喀则', '日喀则', '山南'], ['西双版纳', '保山', '西双版纳', '保山', '楚雄', '大理', '德宏', '德宏', '迪庆', '迪庆', '红河', '昆明', '丽江', '临沧', '临沧', '怒江', '怒江', '普洱', '普洱', '曲靖', '曲靖', '文山', '玉溪', '玉溪', '昭通', '昭通'], ['杭州', '湖州', '嘉兴', '金华', '丽水', '宁波', '衢州', '瑞安', '绍兴', '台州', '温州', '义乌', '乐清', '舟山']]

# %% [markdown]
# # 清洗数据去除重复值

# %%
# 去重函数
def remove_repeat_city(links):
    temp = []
    for i in links:
        newList = []
        for j in i:
            if j not in newList:
                newList.append(j)
        temp.append(newList)
    return temp

# %% [markdown]
# # 验证链接和名称是否对应

# %%
city_links = []
city = []

city_links = remove_repeat_city(city_links_all)
city = remove_repeat_city(city_all)

# 检查二者长度是否相等
print(len(city_all) == len(city_links_all))
for i in range(len(city_links_all)):
    if len(city_all[i]) != len(city_links_all[i]):
        print("Error!")
# Out:
# True

# %% [markdown]
# # 处理异常数据

# %%
# 城市中有为空的情况
# 对于海南，安居客把他放在了青海,不懂什么操作，情况比较复杂，一杯咖啡后决定抛弃海南，对不起海南；
# 对于吉林，列表里只有吉林市的数据而不是吉林省的，单独写一个加进去就行
print(city[7])
print(city[15])
print(city_links[7])
print(city_links[15])
# Out:
# []
# []
# []
# []

# %%
city.pop(7)
city_links.pop(7)
city_links[14] = ['https://www.anjuke.com/fangjia/jilin/']
city[14] = ['吉林']

# %%
print(city)
# Out:
# [['北京', '重庆', '上海', '天津'], ['安庆', '蚌埠', '亳州', '巢湖', '池州', '滁州', '阜阳', '合肥', '和县', '霍邱', '淮北', '淮南', '黄山', '六安', '马鞍山', '宿州', '桐城', '铜陵', '芜湖', '宣城'], ['福州', '龙岩', '南平', '宁德', '莆田', '泉州', '三明', '武夷山', '厦门', '漳州'], ['白银', '定西', '甘南', '嘉峪关', '金昌', '酒泉', '兰州', '临夏', '陇南', '平凉', '庆阳', '天水', '武威', '张掖'], ['潮州', '东莞', '佛山', '广州', '河源', '惠州', '江门', '揭阳', '茂名', '梅州', '清远', '汕头', '汕尾', '韶关', '深圳', '顺德', '台山', '阳春', '阳江', '云浮', '湛江', '肇庆', '中山', '珠海'], ['百色', '北海', '崇左', '防城港', '贵港', '桂林', '河池', '贺州', '来宾', '柳州', '南宁', '钦州', '梧州', '玉林'], ['安顺', '毕节', '贵阳', '六盘水', '黔东南', '黔南', '黔西南', '铜仁', '遵义'], ['保定', '沧州', '承德', '定州', '馆陶', '邯郸', '衡水', '廊坊', '秦皇岛', '石家庄', '唐山', '邢台', '张北', '张家口', '赵县', '正定'], ['大庆', '大兴安岭', '哈尔滨', '鹤岗', '黑河', '佳木斯', '鸡西', '牡丹江', '齐齐哈尔', '七台河', '双鸭山', '绥化', '伊春'], ['安阳', '长葛', '鹤壁', '焦作', '济源', '开封', '漯河', '洛阳', '明港', '南阳', '平顶山', '濮阳', '三门峡', '商丘', '新乡', '信阳', '许昌', '鄢陵', '禹州', '郑州', '周口', '驻马店'], ['恩施', '鄂州', '黄冈', '黄石', '荆门', '荆州', '潜江', '神农架', '十堰', '随州', '天门', '武汉', '襄阳', '咸宁', '仙桃', '孝感', '宜昌'], ['常德', '长沙', '郴州', '衡阳', '怀化', '娄底', '邵阳', '湘潭', '湘西', '益阳', '永州', '岳阳', '张家界', '株洲'], ['常州', '大丰', '淮安', '昆山', '连云港', '南京', '南通', '沭阳', '宿迁', '苏州', '太仓', '泰州', '无锡', '徐州', '盐城', '扬州', '镇江'], ['抚州', '赣州', '吉安', '景德镇', '九江', '南昌', '萍乡', '上饶', '新余', '宜春', '鹰潭', '永新'], ['吉林'], ['鞍山', '本溪', '朝阳', '大连', '丹东', '抚顺', '阜新', '葫芦岛', '锦州', '辽阳', '盘锦', '沈阳', '铁岭', '瓦房店', '营口', '庄河'], ['阿拉善盟', '包头', '巴彦淖尔市', '赤峰', '鄂尔多斯', '海拉尔', '呼和浩特', '呼伦贝尔', '通辽', '乌海', '乌兰察布', '锡林郭勒盟', '兴安盟'], ['固原', '石嘴山', '中卫', '吴忠', '银川'], ['果洛', '海北', '海东', '海南', '海西', '黄南', '西宁', '玉树'], ['安康', '宝鸡', '汉中', '商洛', '铜川', '渭南', '西安', '咸阳', '延安', '榆林'], ['滨州', '德州', '东营', '菏泽', '济南', '济宁', '垦利', '莱芜', '聊城', '临沂', '青岛', '日照', '泰安', '潍坊', '威海', '烟台', '枣庄', '章丘', '诸城', '淄博'], ['长治', '大同', '晋城', '晋中', '临汾', '临猗', '吕梁', '清徐', '朔州', '太原', '忻州', '阳泉', '运城'], ['阿坝', '巴中', '成都', '达州', '德阳', '广元', '甘孜', '广安', '乐山', '凉山', '泸州', '眉山', '绵阳', '南充', '内江', '攀枝花', '遂宁', '雅安', '宜宾', '自贡', '资阳'], ['阿克苏', '阿拉尔', '巴音郭楞', '博尔塔拉', '昌吉', '哈密', '和田', '喀什', '克拉玛依', '克孜勒苏', '石河子', '吐鲁番', '图木舒克', '五家渠', '乌鲁木齐', '伊犁'], ['阿里', '昌都', '拉萨', '林芝', '那曲', '日喀则', '山南'], ['西双版纳', '保山', '楚雄', '大理', '德宏', '迪庆', '红河', '昆明', '丽江', '临沧', '怒江', '普洱', '曲靖', '文山', '玉溪', '昭通'], ['杭州', '湖州', '嘉兴', '金华', '丽水', '宁波', '衢州', '瑞安', '绍兴', '台州', '温州', '义乌', '乐清', '舟山']]

# %%
# 再来检查一遍
for i in range(len(city_links)):
    if len(city[i]) != len(city_links[i]):
        print("Error!")

# %%
# 同样的，省里面得去掉海南，再次向海南道歉
province.pop(7)
province_links.pop(7)
# Out:
# 'http://www.anjuke.com/fangjia/hainan/'

# %%
# 有多少城市呢？
temp = 0
for i in range(len(city)):
    for j in range(len(city[i])):
        temp += 1
print(temp)
# Out:
# 366

# %% [markdown]
# # 收集县区名称以及链接

# %%
# 收集县区
import time
district_links = []
district = []
count_p = 0
for i in range(len(city_links)):
    temp = []
    temp_links = []
    for j in range(len(city_links[i])):
        district_response = requests.get(city_links[i][j],headers=HEADERS)
        if etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()') != []:
            if etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()')[0] != '全部':
                temp.append(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()'))
                temp_links.append(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/@href'))
            else:
                #应对地级市的情况
                temp.append(city[i][j])
                temp_links.append(city_links[i][j])
#         time.sleep(0.5)
        print('get %s' % count_p)
        count_p += 1
    district.append(temp)
    district_links.append(temp_links)
# Out:
# get 0
# get 1
# get 2
# get 3
# get 4
# get 5
# get 6
# get 7
# get 8
# get 9
# get 10
# get 11
# get 12
# get 13
# get 14
# get 15
# get 16
# get 17
# get 18
# get 19
# get 20
# get 21
# get 22
# get 23
# get 24
# get 25
# get 26
# get 27
# get 28
# get 29
# get 30
# get 31
# get 32
# get 33
# get 34
# get 35
# get 36
# get 37
# get 38
# get 39
# get 40
# get 41
# get 42
# get 43
# get 44
# get 45
# get 46
# get 47
# get 48
# get 49
# get 50
# get 51
# get 52
# get 53
# get 54
# get 55
# get 56
# get 57
# get 58
# get 59
# get 60
# get 61
# get 62
# get 63
# get 64
# get 65
# get 66
# get 67
# get 68
# get 69
# get 70
# get 71
# get 72
# get 73
# get 74
# get 75
# get 76
# get 77
# get 78
# get 79
# get 80
# get 81
# get 82
# get 83
# get 84
# get 85
# get 86
# get 87
# get 88
# get 89
# get 90
# get 91
# get 92
# get 93
# get 94
# get 95
# get 96
# get 97
# get 98
# get 99
# get 100
# get 101
# get 102
# get 103
# get 104
# get 105
# get 106
# get 107
# get 108
# get 109
# get 110
# get 111
# get 112
# get 113
# get 114
# get 115
# get 116
# get 117
# get 118
# get 119
# get 120
# get 121
# get 122
# get 123
# get 124
# get 125
# get 126
# get 127
# get 128
# get 129
# get 130
# get 131
# get 132
# get 133
# get 134
# get 135
# get 136
# get 137
# get 138
# get 139
# get 140
# get 141
# get 142
# get 143
# get 144
# get 145
# get 146
# get 147
# get 148
# get 149
# get 150
# get 151
# get 152
# get 153
# get 154
# get 155
# get 156
# get 157
# get 158
# get 159
# get 160
# get 161
# get 162
# get 163
# get 164
# get 165
# get 166
# get 167
# get 168
# get 169
# get 170
# get 171
# get 172
# get 173
# get 174
# get 175
# get 176
# get 177
# get 178
# get 179
# get 180
# get 181
# get 182
# get 183
# get 184
# get 185
# get 186
# get 187
# get 188
# get 189
# get 190
# get 191
# get 192
# get 193
# get 194
# get 195
# get 196
# get 197
# get 198
# get 199
# get 200
# get 201
# get 202
# get 203
# get 204
# get 205
# get 206
# get 207
# get 208
# get 209
# get 210
# get 211
# get 212
# get 213
# get 214
# get 215
# get 216
# get 217
# get 218
# get 219
# get 220
# get 221
# get 222
# get 223
# get 224
# get 225
# get 226
# get 227
# get 228
# get 229
# get 230
# get 231
# get 232
# get 233
# get 234
# get 235
# get 236
# get 237
# get 238
# get 239
# get 240
# get 241
# get 242
# get 243
# get 244
# get 245
# get 246
# get 247
# get 248
# get 249
# get 250
# get 251
# get 252
# get 253
# get 254
# get 255
# get 256
# get 257
# get 258
# get 259
# get 260
# get 261
# get 262
# get 263
# get 264
# get 265
# get 266
# get 267
# get 268
# get 269
# get 270
# get 271
# get 272
# get 273
# get 274
# get 275
# get 276
# get 277
# get 278
# get 279
# get 280
# get 281
# get 282
# get 283
# get 284
# get 285
# get 286
# get 287
# get 288
# get 289
# get 290
# get 291
# get 292
# get 293
# get 294
# get 295
# get 296
# get 297
# get 298
# get 299
# get 300
# get 301
# get 302
# get 303
# get 304
# get 305
# get 306
# get 307
# get 308
# get 309
# get 310
# get 311
# get 312
# get 313
# get 314
# get 315
# get 316
# get 317
# get 318
# get 319
# get 320
# get 321
# get 322
# get 323
# get 324
# get 325
# get 326
# get 327
# get 328
# get 329
# get 330
# get 331
# get 332
# get 333
# get 334
# get 335
# get 336
# get 337
# get 338
# get 339
# get 340
# get 341
# get 342
# get 343
# get 344
# get 345
# get 346
# get 347
# get 348
# get 349
# get 350
# get 351
# get 352
# get 353
# get 354
# get 355
# get 356
# get 357
# get 358
# get 359
# get 360
# get 361
# get 362
# get 363
# get 364
# get 365

# %% [markdown]
# # 验证数据并处理错误数据

# %%
# 验证数据长度,有些市没有列出县区所以会出错，比如安庆，合肥，但是我昨晚试的时候安庆还是被列出来的，可能服务器出于维护期
for i in range(len(district)):
    if len(district[i]) != len(district_links[i]):
            print('error!',i)
    for j in range(len(district[i])):
        if len(district[i][j]) != len(district_links[i][j]):
            print('error!',i,j)
# Out:
# error! 1 0
# error! 1 7
# error! 1 13
# error! 3 8
# error! 3 13
# error! 5 0
# error! 5 2
# error! 5 5
# error! 6 0
# error! 7 2
# error! 7 5
# error! 9 5
# error! 12 0
# error! 12 8
# error! 12 10
# error! 13 4
# error! 15 12
# error! 19 3
# error! 21 9
# error! 22 8
# error! 26 2

# %%
for i in range(len(district)):
    for j in range(len(district[i])):
        if len(district[i][j]) != len(district_links[i][j]):
            print(district[i][j])
            print(district_links[i][j])
# Out:
# 安庆
# http://www.anjuke.com/fangjia/anqing/
# 合肥
# http://www.anjuke.com/fangjia/hf/
# 六安
# http://www.anjuke.com/fangjia/luan/
# 陇南
# http://www.anjuke.com/fangjia/longnan/
# 张掖
# http://www.anjuke.com/fangjia/zhangye/
# 百色
# http://www.anjuke.com/fangjia/baise/
# 崇左
# http://www.anjuke.com/fangjia/chongzuo/
# 桂林
# http://www.anjuke.com/fangjia/guilin/
# 安顺
# http://www.anjuke.com/fangjia/anshun/
# 承德
# http://www.anjuke.com/fangjia/chengde/
# 邯郸
# http://www.anjuke.com/fangjia/handan/
# 开封
# http://www.anjuke.com/fangjia/kaifeng/
# 常州
# http://www.anjuke.com/fangjia/cz/
# 宿迁
# http://www.anjuke.com/fangjia/suqian/
# 太仓
# http://www.anjuke.com/fangjia/taicang/
# 九江
# http://www.anjuke.com/fangjia/jiujiang/
# 铁岭
# http://www.anjuke.com/fangjia/tieling/
# 商洛
# http://www.anjuke.com/fangjia/shangluo/
# 太原
# http://www.anjuke.com/fangjia/ty/
# 乐山
# http://www.anjuke.com/fangjia/leshan/
# 嘉兴
# http://www.anjuke.com/fangjia/jx/

# %%
print(district)
# Out:
# [[['朝阳', '海淀', '东城', '西城', '丰台', '通州', '石景山', '昌平', '大兴', '顺义', '房山', '门头沟', '密云', '怀柔', '平谷', '延庆', '北京周边'], ['渝北', '江北', '沙坪坝', '南岸', '九龙坡', '渝中', '巴南', '大渡口', '北碚', '万州', '璧山', '合川', '永川', '江津', '涪陵', '铜梁', '长寿', '潼南', '荣昌', '开州', '大足', '南川', '垫江', '綦江', '万盛', '梁平', '丰都', '武隆', '奉节', '云阳', '石柱', '秀山', '忠县', '彭水', '黔江', '巫山', '酉阳', '城口', '巫溪', '其它'], ['浦东', '闵行', '宝山', '徐汇', '松江', '嘉定', '静安', '普陀', '杨浦', '虹口', '长宁', '黄浦', '青浦', '奉贤', '金山', '崇明', '上海周边'], ['和平', '河西', '南开', '河北', '河东', '红桥', '滨海新区', '开发区', '西青', '津南', '东丽', '北辰', '大港', '武清', '宝坻', '蓟州', '静海', '宁河', '汉沽', '塘沽', '天津周边']], ['安庆', ['蚌山', '龙子湖', '禹会', '淮上', '怀远', '固镇', '五河', '其他'], ['利辛', '蒙城', '涡阳', '谯城'], ['居巢', '庐江', '含山', '和县', '巢湖周边'], ['贵池', '东至', '石台', '青阳', '池州周边'], ['琅琊', '南谯', '来安', '全椒', '定远', '凤阳', '天长', '明光', '滁州周边'], ['颍州', '颍泉', '颍东', '经济开发区', '界首', '阜南', '太和', '颍上', '临泉'], '合肥', ['历阳镇', '沈巷镇', '白桥镇', '姥桥镇', '功桥镇', '西埠镇', '香泉镇', '乌江镇', '善厚镇', '石杨镇'], ['城关', '河口', '周集', '姚李', '众兴', '新店', '长集', '马店', '扈胡', '霍邱周边'], ['相山', '烈山', '杜集', '濉溪', '淮北周边'], ['田家庵', '大通', '谢家集', '八公山', '潘集', '凤台', '毛集实验区', '寿县'], ['黄山', '徽州', '屯溪', '黄山风景区', '祁门', '休宁', '黟县', '歙县', '黄山周边'], '六安', ['花山', '雨山', '当涂', '博望', '含山', '和县', '其它'], ['埇桥', '泗县', '灵璧', '萧县', '砀山', '其他'], ['文昌', '龙眠', '开发区', '兴尔旺', '金神', '范岗', '大关', '吕亭', '孔城', '青草', '新渡', '黄甲', '双港', '唐湾', '嬉子湖', '桐城周边'], ['铜官', '郊区', '枞阳县', '义安', '铜陵周边'], ['镜湖', '鸠江', '弋江', '无为', '三山', '南陵', '芜湖县', '繁昌', '其他'], ['宣州', '宁国', '郎溪', '广德', '泾县', '绩溪', '旌德', '其它']], [['仓山', '晋安', '鼓楼', '台江', '闽侯', '马尾', '连江', '长乐', '福清', '平潭', '罗源', '永泰', '闽清', '福州周边'], ['新罗', '漳平', '长汀', '永定', '上杭', '武平', '连城'], ['延平', '邵武', '武夷山', '建瓯', '建阳', '顺昌', '浦城', '光泽', '松溪', '政和', '南平周边'], ['蕉城', '福安', '福鼎', '霞浦', '柘荣', '寿宁', '古田', '屏南', '周宁', '东侨区'], ['城厢', '荔城', '秀屿', '涵江', '仙游', '湄洲岛', '南日岛', '黄瓜岛'], ['台商投资区', '鲤城', '丰泽', '洛江', '晋江', '石狮', '惠安', '南安', '安溪', '泉港', '永春', '德化', '金门', '泉州周边'], ['梅列', '三元', '永安', '沙县', '尤溪', '大田', '明溪', '清流', '宁化', '泰宁', '建宁', '将乐', '三明周边'], ['崇安', '武夷', '新丰', '星村镇', '兴田镇', '五夫镇', '武夷山周边'], ['思明', '湖里', '集美', '海沧', '同安', '翔安', '杏林', '厦门周边'], ['角美', '芗城', '龙文', '龙海', '漳浦', '长泰', '东山', '云霄', '平和', '南靖', '诏安', '华安', '其他']], [['白银', '平川', '靖远', '会宁', '景泰', '白银周边'], ['安定', '通渭', '临洮', '漳县', '岷县', '渭源', '陇西', '定西周边'], ['合作', '临潭', '卓尼', '舟曲', '迭部', '玛曲', '碌曲', '夏河', '甘南周边'], ['五一', '新华', '前进', '胜利', '建设', '镜铁山矿区', '雄关', '镜铁', '长城', '嘉峪关周边'], ['永昌', '河西堡', '金川'], ['肃州', '玉门', '敦煌', '金塔', '瓜州', '肃北', '阿克塞', '酒泉周边'], ['城关', '七里河', '安宁', '西固', '永登', '榆中', '皋兰', '红古', '新区', '兰州周边'], ['东乡', '广河', '临夏市', '和政', '积石', '康乐', '临夏', '永靖'], '陇南', ['崆峒', '庄浪', '静宁', '泾川', '灵台', '崇信', '华亭'], ['西峰', '环县', '华池', '庆城', '镇原', '宁县', '正宁', '合水', '庆阳周边'], ['天水', '秦州', '麦积', '清水', '秦安', '甘谷', '武山', '张家川'], ['凉州', '民勤', '古浪', '天祝', '武威周边'], '张掖'], [['湘桥', '枫溪', '潮安', '饶平', '潮州周边'], ['南城', '东城', '虎门', '常平', '樟木头', '塘厦', '厚街', '万江', '寮步', '长安', '凤岗', '莞城', '大朗', '松山湖', '黄江', '清溪', '大岭山', '横沥', '石龙', '沙田', '石碣', '道滘', '麻涌', '东坑', '茶山', '中堂', '桥头', '高埗', '石排', '望牛墩', '洪梅', '企石', '谢岗', '其它'], ['南海', '顺德', '禅城', '三水', '高明', '佛山周边'], ['天河', '番禺', '白云', '海珠', '越秀', '花都', '黄埔', '荔湾', '增城', '南沙', '从化', '萝岗', '广州周边'], ['源城', '紫金', '龙川', '连平', '和平县', '东源', '河源周边'], ['惠城', '惠阳', '博罗', '惠东', '龙门', '仲恺', '大亚湾'], ['北新', '南新', '蓬江区', '江海区', '新会区', '鹤山市', '台山市', '开平市', '恩平市', '江门周边'], ['榕城', '普宁', '揭东', '惠来', '揭西', '其他'], ['茂南', '茂港', '高州', '化州', '信宜', '电白', '其他'], ['梅江', '兴宁', '梅县', '大埔', '丰顺', '五华', '平远', '蕉岭', '梅州周边'], ['清城', '清新', '英德', '连州', '佛冈', '阳山', '连南', '连山'], ['金平', '龙湖', '澄海', '潮阳', '潮南', '濠江', '南澳', '其他'], ['汕尾城区', '海丰', '陆丰', '陆河', '汕尾周边'], ['武江', '浈江', '曲江', '乐昌', '南雄', '新丰', '仁化', '始兴', '乳源', '翁源县', '其它'], ['龙岗', '南山', '宝安', '福田', '龙华', '罗湖', '布吉', '盐田', '坪山', '光明', '大鹏新区', '深圳周边'], ['顺德', '大良', '均安', '乐从', '北滘', '陈村', '勒流', '伦教', '杏坛', '龙江', '容桂'], ['大江', '四九', '都斛', '赤溪', '冲蒌', '斗山', '广海', '川岛', '端芬', '海宴', '三合', '北陡', '深井', '白沙', '台山周边'], ['春城镇', '河塱镇', '松柏镇', '陂面镇', '合水镇', '春湾镇', '岗美镇', '河口镇', '潭水镇', '八甲镇', '双窖镇', '永宁镇', '圭岗镇', '石望镇', '马水镇', '三甲 ...

# %%
# 上面出错的原因是插入错误，我们期望得到的输出应该是  ['安庆' ] 这样子
for i in range(len(district)):
    for j in range(len(district[i])):
        if len(district[i][j]) != len(district_links[i][j]):
            temp = []
            temp_link = []
            temp.append(district[i][j])
            temp_link.append(district_links[i][j])
            district[i][j] = []
            district_links[i][j] = []
            district[i][j].append(temp)
            district_links[i][j].append(temp_link)

# %%
# 看看修补完成没
for i in range(len(district)):
    for j in range(len(district[i])):
        if len(district[i][j]) != len(district_links[i][j]):
            print(district[i][j])
            print(district_links[i][j])

for i in range(len(district)):
    if len(district[i]) != len(district_links[i]):
            print('error!',i)
    for j in range(len(district[i])):
        if len(district[i][j]) != len(district_links[i][j]):
            print('error!',i,j)

# %% [markdown]
# # 用于格式化输入CSV

# %%
# 现在已经获得了县区，市，省的地址和名称，接下来一页页爬取数据就行了，爬到的数据需要格式化一下输入表格中，所以写几个函数来格式化数据

# 返回房价数据
def make_fj(lists):
    temp = []
    for list_ in lists:
        temp.append(list_[:-3])
    return temp

# 返回涨幅数据
def make_fd(lists):
    temp = []
    for list_ in lists:
        if list_[-1] == '↓':
            temp.append('-' + list_[:-1])
        elif list_[-1] == '↑':
            temp.append('+' + list_[:-1])
        else:
            temp.append('0')
    return temp

# 返回年月数据
def make_ym(lists):
    temp_y = []
    temp_m = []
    for list_ in lists:
        temp_y.append(list_[:4])
        temp_m.append(list_[5:7])
    return temp_y,temp_m

# 返回省市数据
def make_pro_city(province, new_city, year, i, j):
    temp_pro = []
    temp_city = []
    for k in range(len(year)):
        temp_pro.append(province[i])
        temp_city.append(new_city[i][j])
    return temp_pro,temp_city

# 返回房价数据
def make_dis(district,i,j,z,year):
    temp = []
    for k in range(len(year)):
        temp.append(district[i][j][z])
    return temp

# 返回链接数据
def make_link(links,i,j,z,year):
    temp = []
    for k in range(len(year)):
        temp.append(links)
    return temp

# 返回区县每年的链接用以访问
def make_each_year(link):
    dis = requests.get(link,headers=HEADERS)
    page = etree.HTML(dis.text)
    link_each_year = page.xpath('//*[starts-with(@class,"fjlist-box")]/h3/a/@href')
    return link_each_year

# %% [markdown]
# # 爬取县区的数据

# %%
import csv
import sys

# 将省中的'一线城市'改为'直辖市'
province[0] = '直辖市'

# 爬取中出现过需要验证的情况，所以需要用添加模式写入csv，并且在循环中加入判断进行接力赛
csv_link='C:/Users/钧娃/Desktop/result_v1.csv'
# 这里得用'a+'打开，不然就覆盖掉了
f = open(csv_link,'a+',encoding='GBK',newline='')
writer = csv.writer(f)
writer.writerow(['year','month','房价','涨跌幅','省','市','县区','链接'])

for i in range(0,len(district)):
    for j in range(len(district[i])):
#         if i == 21 and j < 10:
#             continue
        for z in range(len(district[i][j])):
#             if i == 21 and j == 10 and z < 2:
#                 continue
            link_each_year = make_each_year(district_links[i][j][z])
            for links in link_each_year: 
                dis = requests.get(links,headers=HEADERS)
                page = etree.HTML(dis.text)
                fd= page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/em/text()')
                ym = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/b/text()')
                fj = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/span/text()')
                fd = make_fd(fd)
                fj = make_fj(fj)
                year,month = make_ym(ym)
                pro,cit = make_pro_city(province, city, ym, i, j)
                dis = make_dis(district,i,j,z,ym)
                links = make_link(links,i,j,z,ym)
                rows = zip(year,month,fj,fd,pro,cit,dis,links)
                for row in rows:
                    writer.writerow(row)
#                 time.sleep()
f.close()

# %%
# 通过这个判断程序被终止在那个位置，用于继续爬取而不用从头开始，然后重新设置上面代码接着运行即可
for i in range(len(district)):
    for j in range(len(district[i])):
        for z in range(len(district[i][j])):
            if district_links[i][j][z] == 'http://www.anjuke.com/fangjia/xinzhou/yuanpingb/':
                print(i,j,z)
# Out:
# 21 10 2

# %% [markdown]
# # 进行转换将csv转为要求的xlsx

# %%
# 获得了csv文件，然后转化为xlsx，直接用老师代码的话，会出现如下错误，excel限制表格中的链接不超过65,530个
import pandas as pd
df = pd.read_csv('F:/result.csv', encoding='GBK')
df.to_excel('F:/result.xlsx', encoding='GBK')
# Out:
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2019/keerqinyouyizhongqi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2019/keerqinyouyiqianqi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2018/keerqinyouyiqianqi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2017/keerqinyouyiqianqi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2019/xinganmengzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2018/xinganmengzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xinganmeng2017/xinganmengzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/guyuan2019/yuanzhouqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/guyuan2019/xijixian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/guyuan2019/pengyangxian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/guyuan2019/jingyuanxian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2019/dawukou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2019/huinong/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2019/pingluoa/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2019/shizuishanzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2018/shizuishanzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2017/shizuishanzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2016/shizuishanzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shizuishan2015/shizuishanzhoubian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weizhong2019/shapotou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weizhong2018/shapotou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weizhong2017/shapotou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weizhong2016/shapotou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weizhong2019/zhongning/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wuzhong2019/litong/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wuzhong2019/qingtongxia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wuzhong2019/hongsipu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2019/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2018/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2017/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2016/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2014/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2013/yongningx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2019/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2018/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2017/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2016/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2015/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2014/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2013/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2012/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2011/helanx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2019/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2018/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2017/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2016/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2015/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2014/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2013/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2012/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2011/xingqinggongyuao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2019/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2018/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2017/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2016/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2015/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2014/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2013/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2012/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2011/jinfenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2019/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2018/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2017/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2016/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2015/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2014/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2013/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2012/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yinchuan2011/xixiangtanh/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hainan2019/gonghexian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/chengxiabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/chengxiabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/chengxiabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2016/chengxiabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2015/chengxiabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/chengzhongbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/chengzhongbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/chengzhongbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2016/chengzhongbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2015/chengzhongbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/chengdongabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/chengdongabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/chengdongabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2016/chengdongabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2015/chengdongabcdef/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/chengbeiabcdefg/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/chengbeiabcdefg/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/chengbeiabcdefg/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2016/chengbeiabcdefg/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2015/chengbeiabcdefg/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/yuanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/yuanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/datonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/datonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/datonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2019/zhongab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2018/zhongab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xining2017/zhongab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2019/hanbin/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2018/hanbin/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2017/hanbin/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2016/hanbin/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2015/hanbin/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2019/langao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2019/ankanghy/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/ankang2019/ankangpl/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/weibinb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2018/weibinb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2017/weibinb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2016/weibinb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2015/weibinb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/jintaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2018/jintaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2017/jintaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2016/jintaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2015/jintaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/chencangb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2018/chencangb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2017/chencangb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2016/chencangb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2015/chencangb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/shanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2018/shanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2017/shanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2016/shanab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/meixianb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/fengxiang/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/taibai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2019/baojishi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/baoji2018/baojishi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/hantaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2018/hantaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2017/hantaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2016/hantaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2015/hantaib/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/chenggub/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2018/chenggub/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2017/chenggub/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/nanzhengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2018/nanzhengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2017/nanzhengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2016/nanzhengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2015/nanzhengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/yangxianb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/mianxianb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2018/mianxianb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/xixiangbc/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/ningqiangx/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/hanzhong2019/zhenbax/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/shangluo2019/shangzhou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/tongchuan2019/yintaiqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/tongchuan2019/yaozhouqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/linwei/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/linwei/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/hanchengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/hanchengb/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/tongguan/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/tongguan/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/dalixian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/dalixian/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/heyang/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/puchenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/puchenga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/fuping/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/fuping/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/chengcheng/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2019/weinan/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/weinan2018/weinan/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2019/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2018/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2017/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2016/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2015/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2014/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2013/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2012/weiyangq/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2019/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2018/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2017/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2016/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2015/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2014/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2013/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2012/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2011/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2010/yantaqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2019/lianhuqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2018/lianhuqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/xa2017/lianhuqu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
# ...
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2019/dongtou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2018/dongtou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2017/dongtou/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2019/taishun/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2018/taishun/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/wenzhou2017/taishun/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/chouchengab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/chouchengab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/chouchengab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/chouchengab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/chouchengab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/beiyuana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/beiyuana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/beiyuana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/beiyuana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/beiyuana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/choujiangab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/choujiangab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/choujiangab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/choujiangab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/choujiangab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/jiangdonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/jiangdonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/jiangdonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/jiangdonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/jiangdonga/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/houzhaiab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/houzhaiab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/houzhaiab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/houzhaiab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/houzhaiab/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/sanlia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/sanlia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/sanlia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/sanlia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2015/sanlia/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/yiwushiqua/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/yiwushiqua/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/yiwushiqua/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/yiwushiqua/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2019/yiwuzhoubiana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2018/yiwuzhoubiana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2017/yiwuzhoubiana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yiwu2016/yiwuzhoubiana/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yueqing2019/yqlecheng/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yueqing2019/yqliushi/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yueqing2019/yqhongqiao/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yueqing2019/yqqingjiang/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/yueqing2019/yqbeibaixiang/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2019/dinghai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2018/dinghai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2017/dinghai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2016/dinghai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2015/dinghai/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2019/putuob/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2018/putuob/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2017/putuob/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2016/putuob/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2015/putuob/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2019/shanabcd/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2018/shanabcd/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2019/abcdefghijk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# D:\Anaconda\lib\site-packages\xlsxwriter\worksheet.py:840: UserWarning: Ignoring URL 'http://www.anjuke.com/fangjia/zhoushan2018/abcdefghijk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))

# %%
# 所以用另一种方法，建立一个writer，规定将string转化为url为否，即不转化
writer = pd.ExcelWriter(r'F:/result.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer)
writer.close()

# %%
# 完结保存即可，最终我们爬取了92030行数据，其实还可以加个几百行，因为没有爬取上海北京这些城市的平均房价。

# %% [markdown]
# # 我们组小伙伴发现没有海南省但是有海口市，最后单独补上就可以了

# %%
import requests
from lxml import etree
import csv
import sys

# 收集海口的县区
import time
haikou_link = 'https://www.anjuke.com/fangjia/haikou/'
temp = []
temp_links = []
district_response = requests.get(haikou_link,headers=HEADERS)
if etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()') != []:
    temp=(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()'))
    temp_links=(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/@href'))

# %%
temp_links
# Out:
# ['http://www.anjuke.com/fangjia/haikou/meilan/',
#  'http://www.anjuke.com/fangjia/haikou/longhuab/',
#  'http://www.anjuke.com/fangjia/haikou/xiuying/',
#  'http://www.anjuke.com/fangjia/haikou/qiongshan/',
#  'http://www.anjuke.com/fangjia/haikou/chengmaixiana/',
#  'http://www.anjuke.com/fangjia/haikou/lingaoxian/',
#  'http://www.anjuke.com/fangjia/haikou/wenchangshia/',
#  'http://www.anjuke.com/fangjia/haikou/danzhoushia/',
#  'http://www.anjuke.com/fangjia/haikou/qionghaishi/',
#  'http://www.anjuke.com/fangjia/haikou/haikouzhoubian/',
#  'http://www.anjuke.com/fangjia/haikou/qitaby/']

# %%
csv_link='C:/Users/钧娃/Desktop/result.csv'
# 这里得用'a+'打开，不然就覆盖掉了
f = open(csv_link,'a+',encoding='GBK',newline='')
writer = csv.writer(f)
# writer.writerow(['year','month','房价','涨跌幅','省','市','县区','链接'])
pro = []
cit = []

for i in range(len(temp)):
    pro.append('海南')
    cit.append('海口')

for i in range(len(temp)):
    link_each_year = make_each_year(temp_links[i])
    for links in link_each_year: 
        dis = requests.get(links,headers=HEADERS)
        page = etree.HTML(dis.text)
        fd= page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/em/text()')
        ym = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/b/text()')
        fj = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/span/text()')
        fd = make_fd(fd)
        fj = make_fj(fj)
        year,month = make_ym(ym)
        dis = []
        links = []
        for ii in range(len(ym)):
            dis.append(temp[i])
            links.append(temp_links[i])
        rows = zip(year,month,fj,fd,pro,cit,dis,links)
        for row in rows:
            writer.writerow(row)
f.close()

# %%
import pandas as pd
df = pd.read_csv('F:/result.csv', encoding='GBK')
writer = pd.ExcelWriter(r'F:/result.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer)
writer.close()

# %% [markdown]
# # 又补充了三亚的数据

# %%
import requests
from lxml import etree
import csv
import sys

# 收集海口的县区
import time
haikou_link = 'https://www.anjuke.com/fangjia/sanya/'
temp = []
temp_links = []
district_response = requests.get(haikou_link,headers=HEADERS)
if etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()') != []:
    temp=(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/text()'))
    temp_links=(etree.HTML(district_response.text).xpath('/html/body/div[2]/div[2]/div/span[2]/a/@href'))

# %%
temp_links
# Out:
# ['http://www.anjuke.com/fangjia/sanya/hedonga/',
#  'http://www.anjuke.com/fangjia/sanya/sanyawan/',
#  'http://www.anjuke.com/fangjia/sanya/lingshuilub/',
#  'http://www.anjuke.com/fangjia/sanya/dadonghai/',
#  'http://www.anjuke.com/fangjia/sanya/haitangwan/',
#  'http://www.anjuke.com/fangjia/sanya/wanning/',
#  'http://www.anjuke.com/fangjia/sanya/hexiangxj/',
#  'http://www.anjuke.com/fangjia/sanya/yacheng/',
#  'http://www.anjuke.com/fangjia/sanya/yalongwan/',
#  'http://www.anjuke.com/fangjia/sanya/xiaodonghai/',
#  'http://www.anjuke.com/fangjia/sanya/tainyaqu/',
#  'http://www.anjuke.com/fangjia/sanya/haitangqu/',
#  'http://www.anjuke.com/fangjia/sanya/fenghuangdao/',
#  'http://www.anjuke.com/fangjia/sanya/jiyangb/',
#  'http://www.anjuke.com/fangjia/sanya/yanzhouqu/',
#  'http://www.anjuke.com/fangjia/sanya/sanyazhoubain/',
#  'http://www.anjuke.com/fangjia/sanya/qitaaaa/']

# %%
csv_link='C:/Users/钧娃/Desktop/result.csv'
# 这里得用'a+'打开，不然就覆盖掉了
f = open(csv_link,'a+',encoding='GBK',newline='')
writer = csv.writer(f)
# writer.writerow(['year','month','房价','涨跌幅','省','市','县区','链接'])
pro = []
cit = []

for i in range(len(temp)):
    pro.append('海南')
    cit.append('三亚')

for i in range(len(temp)):
    link_each_year = make_each_year(temp_links[i])
    for links in link_each_year: 
        dis = requests.get(links,headers=HEADERS)
        page = etree.HTML(dis.text)
        fd= page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/em/text()')
        ym = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/b/text()')
        fj = page.xpath('//*[starts-with(@class,"fjlist-box")][1]/ul/li/a/span/text()')
        fd = make_fd(fd)
        fj = make_fj(fj)
        year,month = make_ym(ym)
        dis = []
        links = []
        for ii in range(len(ym)):
            dis.append(temp[i])
            links.append(temp_links[i])
        rows = zip(year,month,fj,fd,pro,cit,dis,links)
        for row in rows:
            writer.writerow(row)
f.close()

# %%
import pandas as pd
df = pd.read_csv('F:/result.csv', encoding='GBK')
writer = pd.ExcelWriter(r'F:/result.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
df.to_excel(writer)
writer.close()

# %% [markdown]
# # 最终我们爬取了94018行数据
